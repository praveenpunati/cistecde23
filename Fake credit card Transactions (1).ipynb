# %%
import pandas as pd
import numpy as np

# %%
# Series is a column
a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
#print(myvar[0]
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64
# 1

# %%
a = [1, 2,6,8,10]
b
myvar = pd.Series(a, index = ["x", "y", "z","s","t","dd"])

print(myvar)
# Out:
# x       1
# y       2
# z     abc
# s       6
# t       8
# dd     10
# dtype: object

# %%
#createdataframe
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)

# %%
df=pd.read_csv("C:/Training/data/archive/fraudTest.csv")

# %%
df.shape
# Out:
# (555719, 23)

# %%
data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
data.tail()
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                      merchant        category     amt    first     last  \
# 555714  fraud_Reilly and Sons  health_fitness   43.77  Michael    Olson
# 555715   fraud_Hoppe-Parisian       kids_pets  111.84     Jose  Vasquez
# 555716        fraud_Rau-Robel       kids_pets   86.88      Ann   Lawson
# 555717  fraud_Breitenberg LLC          travel    7.99     Eric  Preston
# 555718      fraud_Dare-Marvin   entertainment   38.13   Samuel     Frey
#
#        gender                      street  ...      lat      long  city_pop  \
# 555714      M         558 Michael Estates  ...  40.4931  -91.8912       519
# ...

# %%
data.describe()
# Out:
#              amount
# count  1.000000e+07
# mean   1.632089e+02
# std    1.608585e+02
# min    0.000000e+00
# 25%    8.300000e+00
# 50%    1.001700e+02
# 75%    2.999900e+02
# max    5.000000e+02

# %%
print("total amount:")
df1 =  data.groupby('amt')['amt'].sum()
df1 =  data.amt.sum()
print(df1)
x = round(df1, -2)
print("Numbers rounded to the nearest 100")
print(x)
# Out:
# total amount:
# 38562903.11
# Numbers rounded to the nearest 100
# 38562900.0

# %%
print("transaction count:")
df2 =  data.transaction_id.count()
print(df2)
x = round(df2, -2)
print("Numbers rounded to the nearest 100")
print(x)
# Out:
# transaction count:
# 10000000
# Numbers rounded to the nearest 100
# 10000000

# %%
print("business count:")
df3 =  data.business.count()
print(df3)
x = round(df3, -2)
print("Numbers rounded to the nearest 100")
print(x)
# Out:
# business count:
# 9993455
# Numbers rounded to the nearest 100
# 9993500

# %%
print("What is the average transaction amount?")
df4 =  df1/df2
print(df4)
# Out:
# What is the average transaction amount?
# 163.20886244700003

# %%
print("What business generated the most volume?")
df5 =  data.groupby('business')['transaction_id'].count()
print(df5)
# Out:
# What business generated the most volume?
# business
# 1-800 CONTACTS                              6759
# 1-800-FLOWERS.COM, INC.                     6596
# 1915 South | Ashley HomeStore               6589
# 21st Century HealthCare, Inc.               6632
# 2nd & Charles                               6518
# 3 Day Blinds                                6603
# 5.11 Tactical                               6705
# 7-Eleven                                    6591
# 99 Cents Only Stores                        6777
# A&W Restaurants, Inc.                       6633
# ACCO Brands                                 6540
# ADW Acosta                                  6671
# AJ's Market & Natural Foods                 6487
# AKIRA Chicago                               6598
# ALDI USA                                    6429
# AMERICAN EAGLE OUTFITTERS INC.              6681
# AMG Automotive                              6556
# ANN INC (Ann Taylor | LOFT | Lou & Grey)    6560
# ...
